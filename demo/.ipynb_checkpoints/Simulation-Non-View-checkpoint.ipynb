# %% [markdown]
# # Load Library
# load global library

# %%
import sys
import os

# %% [markdown]
# load local library

# %%
sys.path.append(os.path.join(os.getcwd() , ".."))
import lib.NZMap as nzmap
import lib.NZRenderer as renderer
import lib.NZSimulation as simulation
import lib.NZEvaluator as evaluator

# %% [markdown]
# # Path to file

# %%
dataDirectory = os.path.join("..","osmdata")
filename = "TX-To-TU.osm"
filepath = os.path.join(dataDirectory,filename)

# %% [markdown]
# # Load Data

# %%
osmMap = nzmap.readFile(filepath)
osmMap.restructureRoad()
# Out:
# Road 1 : 13444 cell
# Road 2 : 26 cell
# Road 3 : 54 cell
# Road 4 : 4 cell
# Road 5 : 8 cell
# Road 6 : 42 cell
# Road 7 : 7 cell
# Road 8 : 4 cell
# Road 9 : 15 cell
# Road 10 : 10 cell
# Road 11 : 53 cell
# Road 12 : 63 cell
# Road 13 : 42 cell
# Road 14 : 26 cell
# Road 15 : 18 cell
# Road 16 : 61 cell

# %% [markdown]
# # Simulate

# %%
sim = simulation.Simulation(osmMap)
sim.initialize(500, 10)
# Out:
# Processing = 1/100 agents
# Processing = 2/100 agents
# Processing = 3/100 agents
# Processing = 4/100 agents
# Processing = 5/100 agents
# Processing = 6/100 agents
# Processing = 7/100 agents
# Processing = 8/100 agents
# Processing = 9/100 agents
# Processing = 10/100 agents
# Processing = 11/100 agents
# Selected Cell is out of bounds, selecting another random cell
# Processing = 12/100 agents
# Processing = 13/100 agents
# Processing = 14/100 agents
# Processing = 15/100 agents
# Processing = 16/100 agents
# Processing = 17/100 agents
# Processing = 18/100 agents
# Selected Cell is out of bounds, selecting another random cell
# Processing = 19/100 agents
# Processing = 20/100 agents
# Processing = 21/100 agents
# Processing = 22/100 agents
# Processing = 23/100 agents
# Selected Cell is out of bounds, selecting another random cell
# Processing = 24/100 agents
# Processing = 25/100 agents
# Processing = 26/100 agents
# Processing = 27/100 agents
# Processing = 28/100 agents
# Selected Cell is out of bounds, selecting another random cell
# Processing = 29/100 agents
# Processing = 30/100 agents
# Processing = 31/100 agents
# Processing = 32/100 agents
# Processing = 33/100 agents
# Processing = 34/100 agents
# Processing = 35/100 agents
# Processing = 36/100 agents
# Processing = 37/100 agents
# Processing = 38/100 agents
# Selected Cell is out of bounds, selecting another random cell
# Processing = 39/100 agents
# Processing = 40/100 agents
# Processing = 41/100 agents
# Processing = 42/100 agents
# Selected Cell is out of bounds, selecting another random cell
# Processing = 43/100 agents
# Processing = 44/100 agents
# Processing = 45/100 agents
# Selected Cell is out of bounds, selecting another random cell
# Processing = 46/100 agents
# Processing = 47/100 agents
# Processing = 48/100 agents
# Processing = 49/100 agents
# Processing = 50/100 agents
# Selected Cell is out of bounds, selecting another random cell
# Processing = 51/100 agents
# Processing = 52/100 agents
# Processing = 53/100 agents
# Processing = 54/100 agents
# Processing = 55/100 agents
# Processing = 56/100 agents
# Selected Cell is out of bounds, selecting another random cell
# Processing = 57/100 agents
# Selected Cell is out of bounds, selecting another random cell
# Processing = 58/100 agents
# Processing = 59/100 agents
# Processing = 60/100 agents
# Processing = 61/100 agents
# Processing = 62/100 agents
# Processing = 63/100 agents
# Processing = 64/100 agents
# Processing = 65/100 agents
# Processing = 66/100 agents
# Processing = 67/100 agents
# Processing = 68/100 agents
# Processing = 69/100 agents
# Processing = 70/100 agents
# Processing = 71/100 agents
# Processing = 72/100 agents
# Processing = 73/100 agents
# Processing = 74/100 agents
# Processing = 75/100 agents
# Processing = 76/100 agents
# Processing = 77/100 agents
# Processing = 78/100 agents
# Processing = 79/100 agents
# Processing = 80/100 agents
# Processing = 81/100 agents
# Processing = 82/100 agents
# Processing = 83/100 agents
# Selected Cell is out of bounds, selecting another random cell
# Processing = 84/100 agents
# Processing = 85/100 agents
# Processing = 86/100 agents
# Processing = 87/100 agents
# Selected Cell is out of bounds, selecting another random cell
# Processing = 88/100 agents
# Processing = 89/100 agents
# Processing = 90/100 agents
# Processing = 91/100 agents
# Processing = 92/100 agents
# Processing = 93/100 agents
# Processing = 94/100 agents
# Selected Cell is out of bounds, selecting another random cell
# Processing = 95/100 agents
# Processing = 96/100 agents
# Processing = 97/100 agents
# Processing = 98/100 agents
# Processing = 99/100 agents
# Processing = 100/100 agents

# %%
print(sim)
# Out:
# Step count = 0
# Total agent = 100
# 	Total Unevacuated = 100
# 	Total Evacuated = 0
# Total Evac Point = 10
# 	Total Filled Evac Point = 0

# %% [markdown]
# # Render Map

# %%
while (not evaluator.evaluate(sim)):
    sim.step()
    print(sim)
# Out:
# Step count = 1
# Total agent = 100
# 	Total Unevacuated = 100
# 	Total Evacuated = 0
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Step count = 2
# Total agent = 100
# 	Total Unevacuated = 100
# 	Total Evacuated = 0
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Evac Success
# Step count = 3
# Total agent = 100
# 	Total Unevacuated = 99
# 	Total Evacuated = 1
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Step count = 4
# Total agent = 100
# 	Total Unevacuated = 99
# 	Total Evacuated = 1
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Step count = 5
# Total agent = 100
# 	Total Unevacuated = 99
# 	Total Evacuated = 1
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Step count = 6
# Total agent = 100
# 	Total Unevacuated = 99
# 	Total Evacuated = 1
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Evac Success
# Evac Success
# Step count = 7
# Total agent = 100
# 	Total Unevacuated = 97
# 	Total Evacuated = 3
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Step count = 8
# Total agent = 100
# 	Total Unevacuated = 97
# 	Total Evacuated = 3
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Evac Success
# Step count = 9
# Total agent = 100
# 	Total Unevacuated = 96
# 	Total Evacuated = 4
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Step count = 10
# Total agent = 100
# 	Total Unevacuated = 96
# 	Total Evacuated = 4
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Step count = 11
# Total agent = 100
# 	Total Unevacuated = 96
# 	Total Evacuated = 4
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Step count = 12
# Total agent = 100
# 	Total Unevacuated = 96
# 	Total Evacuated = 4
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Evac Success
# Evac Success
# Step count = 13
# Total agent = 100
# 	Total Unevacuated = 94
# 	Total Evacuated = 6
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Evac Success
# Step count = 14
# Total agent = 100
# 	Total Unevacuated = 93
# 	Total Evacuated = 7
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Evac Success
# Step count = 15
# Total agent = 100
# 	Total Unevacuated = 92
# 	Total Evacuated = 8
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Step count = 16
# Total agent = 100
# 	Total Unevacuated = 88
# 	Total Evacuated = 12
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Evac Success
# Step count = 17
# Total agent = 100
# 	Total Unevacuated = 87
# 	Total Evacuated = 13
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Evac Success
# Step count = 18
# Total agent = 100
# 	Total Unevacuated = 86
# 	Total Evacuated = 14
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Step count = 19
# Total agent = 100
# 	Total Unevacuated = 86
# 	Total Evacuated = 14
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Evac Success
# Evac Success
# Step count = 20
# Total agent = 100
# 	Total Unevacuated = 84
# 	Total Evacuated = 16
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Step count = 21
# Total agent = 100
# 	Total Unevacuated = 84
# 	Total Evacuated = 16
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Evac Success
# Evac Success
# Step count = 22
# Total agent = 100
# 	Total Unevacuated = 82
# 	Total Evacuated = 18
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Evac Success
# Step count = 23
# Total agent = 100
# 	Total Unevacuated = 81
# 	Total Evacuated = 19
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Evac Success
# Step count = 24
# Total agent = 100
# 	Total Unevacuated = 80
# 	Total Evacuated = 20
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Evac Success
# Evac Success
# Evac Success
# Step count = 25
# Total agent = 100
# 	Total Unevacuated = 77
# 	Total Evacuated = 23
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Evac Success
# Step count = 26
# Total agent = 100
# 	Total Unevacuated = 76
# 	Total Evacuated = 24
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Evac Success
# Evac Success
# Evac Success
# Step count = 27
# Total agent = 100
# 	Total Unevacuated = 73
# 	Total Evacuated = 27
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Evac Success
# Evac Success
# Step count = 28
# Total agent = 100
# 	Total Unevacuated = 71
# 	Total Evacuated = 29
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Evac Success
# Evac Success
# Evac Success
# Step count = 29
# Total agent = 100
# 	Total Unevacuated = 68
# 	Total Evacuated = 32
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Evac Success
# Step count = 30
# Total agent = 100
# 	Total Unevacuated = 67
# 	Total Evacuated = 33
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Step count = 31
# Total agent = 100
# 	Total Unevacuated = 63
# 	Total Evacuated = 37
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Step count = 32
# Total agent = 100
# 	Total Unevacuated = 63
# 	Total Evacuated = 37
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Evac Success
# Evac Success
# Evac Success
# Step count = 33
# Total agent = 100
# 	Total Unevacuated = 60
# 	Total Evacuated = 40
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Evac Success
# Evac Success
# Step count = 34
# Total agent = 100
# 	Total Unevacuated = 58
# 	Total Evacuated = 42
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Evac Success
# Evac Success
# Evac Success
# Step count = 35
# Total agent = 100
# 	Total Unevacuated = 55
# 	Total Evacuated = 45
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Evac Success
# Evac Success
# Evac Success
# Step count = 36
# Total agent = 100
# 	Total Unevacuated = 52
# 	Total Evacuated = 48
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Evac Success
# Evac Success
# Evac Success
# Step count = 37
# Total agent = 100
# 	Total Unevacuated = 49
# 	Total Evacuated = 51
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Step count = 38
# Total agent = 100
# 	Total Unevacuated = 49
# 	Total Evacuated = 51
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Evac Success
# Evac Success
# Step count = 39
# Total agent = 100
# 	Total Unevacuated = 47
# 	Total Evacuated = 53
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Evac Success
# Evac Success
# Evac Success
# Step count = 40
# Total agent = 100
# 	Total Unevacuated = 44
# 	Total Evacuated = 56
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Evac Success
# Evac Success
# Step count = 41
# Total agent = 100
# 	Total Unevacuated = 42
# 	Total Evacuated = 58
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Evac Success
# Evac Success
# Step count = 42
# Total agent = 100
# 	Total Unevacuated = 40
# 	Total Evacuated = 60
# Total Evac Point = 10
# 	Total Filled Evac Point = 0
#
# Evac Success
# Step count = 43
# Total agent = 100
# 	Total Unevacuated = 39
# 	Total Evacuated = 61
# Total Evac Point = 10
# 	Total Filled Evac Point = 1
#
# Step count = 44
# Total agent = 100
# 	Total Unevacuated = 39
# 	Total Evacuated = 61
# Total Evac Point = 10
# 	Total Filled Evac Point = 1
#
# Evacpoint full, finding next evac point
# Step count = 45
# Total agent = 100
# 	Total Unevacuated = 39
# 	Total Evacuated = 61
# Total Evac Point = 10
# 	Total Filled Evac Point = 1
#
# Evac Success
# Step count = 46
# Total agent = 100
# 	Total Unevacuated = 38
# 	Total Evacuated = 62
# Total Evac Point = 10
# 	Total Filled Evac Point = 1
#
# Evac Success
# Step count = 47
# Total agent = 100
# 	Total Unevacuated = 37
# 	Total Evacuated = 63
# Total Evac Point = 10
# 	Total Filled Evac Point = 1
#
# Evac Success
# Evac Success
# Step count = 48
# Total agent = 100
# 	Total Unevacuated = 35
# 	Total Evacuated = 65
# Total Evac Point = 10
# 	Total Filled Evac Point = 1
#
# Evac Success
# Step count = 49
# Total agent = 100
# 	Total Unevacuated = 34
# 	Total Evacuated = 66
# Total Evac Point = 10
# 	Total Filled Evac Point = 2
#
# Evac Success
# Evacpoint full, finding next evac point
# Evacpoint full, finding next evac point
# Step count = 50
# Total agent = 100
# 	Total Unevacuated = 33
# 	Total Evacuated = 67
# Total Evac Point = 10
# 	Total Filled Evac Point = 2
#
# Evac Success
# Step count = 51
# Total agent = 100
# 	Total Unevacuated = 32
# 	Total Evacuated = 68
# Total Evac Point = 10
# 	Total Filled Evac Point = 2
#
# Step count = 52
# Total agent = 100
# 	Total Unevacuated = 32
# 	Total Evacuated = 68
# Total Evac Point = 10
# 	Total Filled Evac Point = 2
#
# Evac Success
# Step count = 53
# Total agent = 100
# 	Total Unevacuated = 31
# 	Total Evacuated = 69
# Total Evac Point = 10
# 	Total Filled Evac Point = 2
#
# Evac Success
# Step count = 54
# Total agent = 100
# 	Total Unevacuated = 30
# 	Total Evacuated = 70
# Total Evac Point = 10
# 	Total Filled Evac Point = 2
#
# Evac Success
# Evac Success
# Step count = 55
# Total agent = 100
# 	Total Unevacuated = 28
# 	Total Evacuated = 72
# Total Evac Point = 10
# 	Total Filled Evac Point = 2
#
# Evac Success
# Evac Success
# Step count = 56
# Total agent = 100
# 	Total Unevacuated = 26
# 	Total Evacuated = 74
# Total Evac Point = 10
# 	Total Filled Evac Point = 2
#
# Evac Success
# Evac Success
# Step count = 57
# Total agent = 100
# 	Total Unevacuated = 24
# 	Total Evacuated = 76
# Total Evac Point = 10
# 	Total Filled Evac Point = 3
#
# Evacpoint full, finding next evac point
# Step count = 58
# Total agent = 100
# 	Total Unevacuated = 24
# 	Total Evacuated = 76
# Total Evac Point = 10
# 	Total Filled Evac Point = 3
#
# Evac Success
# Step count = 59
# Total agent = 100
# 	Total Unevacuated = 23
# 	Total Evacuated = 77
# Total Evac Point = 10
# 	Total Filled Evac Point = 3
#
# Step count = 60
# Total agent = 100
# 	Total Unevacuated = 23
# 	Total Evacuated = 77
# Total Evac Point = 10
# 	Total Filled Evac Point = 3
#
# Evacpoint full, finding next evac point
# Step count = 61
# Total agent = 100
# 	Total Unevacuated = 23
# 	Total Evacuated = 77
# Total Evac Point = 10
# 	Total Filled Evac Point = 3
#
# Step count = 62
# Total agent = 100
# 	Total Unevacuated = 23
# 	Total Evacuated = 77
# Total Evac Point = 10
# 	Total Filled Evac Point = 3
#
# Evac Success
# Evac Success
# Evac Success
# Step count = 63
# Total agent = 100
# 	Total Unevacuated = 20
# 	Total Evacuated = 80
# Total Evac Point = 10
# 	Total Filled Evac Point = 3
#
# Evac Success
# Step count = 64
# Total agent = 100
# 	Total Unevacuated = 19
# 	Total Evacuated = 81
# Total Evac Point = 10
# 	Total Filled Evac Point = 3
#
# Evac Success
# Evac Success
# Step count = 65
# Total agent = 100
# 	Total Unevacuated = 17
# 	Total Evacuated = 83
# Total Evac Point = 10
# 	Total Filled Evac Point = 4
#
# Evac Success
# Step count = 66
# Total agent = 100
# 	Total Unevacuated = 16
# 	Total Evacuated = 84
# Total Evac Point = 10
# 	Total Filled Evac Point = 4
#
# Step count = 67
# Total agent = 100
# 	Total Unevacuated = 16
# 	Total Evacuated = 84
# Total Evac Point = 10
# 	Total Filled Evac Point = 4
#
# Evac Success
# Step count = 68
# Total agent = 100
# 	Total Unevacuated = 15
# 	Total Evacuated = 85
# Total Evac Point = 10
# 	Total Filled Evac Point = 5
#
# Step count = 69
# Total agent = 100
# 	Total Unevacuated = 15
# 	Total Evacuated = 85
# Total Evac Point = 10
# 	Total Filled Evac Point = 5
#
# Step count = 70
# Total agent = 100
# 	Total Unevacuated = 15
# 	Total Evacuated = 85
# Total Evac Point = 10
# 	Total Filled Evac Point = 5
#
# Step count = 71
# Total agent = 100
# 	Total Unevacuated = 15
# 	Total Evacuated = 85
# Total Evac Point = 10
# 	Total Filled Evac Point = 5
#
# Evac Success
# Step count = 72
# Total agent = 100
# 	Total Unevacuated = 14
# 	Total Evacuated = 86
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 73
# Total agent = 100
# 	Total Unevacuated = 14
# 	Total Evacuated = 86
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 74
# Total agent = 100
# 	Total Unevacuated = 14
# 	Total Evacuated = 86
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 75
# Total agent = 100
# 	Total Unevacuated = 14
# 	Total Evacuated = 86
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 76
# Total agent = 100
# 	Total Unevacuated = 14
# 	Total Evacuated = 86
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 77
# Total agent = 100
# 	Total Unevacuated = 14
# 	Total Evacuated = 86
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 78
# Total agent = 100
# 	Total Unevacuated = 14
# 	Total Evacuated = 86
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Evacpoint full, finding next evac point
# Step count = 79
# Total agent = 100
# 	Total Unevacuated = 14
# 	Total Evacuated = 86
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 80
# Total agent = 100
# 	Total Unevacuated = 14
# 	Total Evacuated = 86
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 81
# Total agent = 100
# 	Total Unevacuated = 14
# 	Total Evacuated = 86
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 82
# Total agent = 100
# 	Total Unevacuated = 14
# 	Total Evacuated = 86
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 83
# Total agent = 100
# 	Total Unevacuated = 14
# 	Total Evacuated = 86
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 84
# Total agent = 100
# 	Total Unevacuated = 14
# 	Total Evacuated = 86
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 85
# Total agent = 100
# 	Total Unevacuated = 14
# 	Total Evacuated = 86
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 86
# Total agent = 100
# 	Total Unevacuated = 14
# 	Total Evacuated = 86
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 87
# Total agent = 100
# 	Total Unevacuated = 14
# 	Total Evacuated = 86
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Evac Success
# Step count = 88
# Total agent = 100
# 	Total Unevacuated = 13
# 	Total Evacuated = 87
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 89
# Total agent = 100
# 	Total Unevacuated = 13
# 	Total Evacuated = 87
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 90
# Total agent = 100
# 	Total Unevacuated = 13
# 	Total Evacuated = 87
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 91
# Total agent = 100
# 	Total Unevacuated = 13
# 	Total Evacuated = 87
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 92
# Total agent = 100
# 	Total Unevacuated = 13
# 	Total Evacuated = 87
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 93
# Total agent = 100
# 	Total Unevacuated = 13
# 	Total Evacuated = 87
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 94
# Total agent = 100
# 	Total Unevacuated = 13
# 	Total Evacuated = 87
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 95
# Total agent = 100
# 	Total Unevacuated = 13
# 	Total Evacuated = 87
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 96
# Total agent = 100
# 	Total Unevacuated = 13
# 	Total Evacuated = 87
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 97
# Total agent = 100
# 	Total Unevacuated = 13
# 	Total Evacuated = 87
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 98
# Total agent = 100
# 	Total Unevacuated = 13
# 	Total Evacuated = 87
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 99
# Total agent = 100
# 	Total Unevacuated = 13
# 	Total Evacuated = 87
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 100
# Total agent = 100
# 	Total Unevacuated = 13
# 	Total Evacuated = 87
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 101
# Total agent = 100
# 	Total Unevacuated = 13
# 	Total Evacuated = 87
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 102
# Total agent = 100
# 	Total Unevacuated = 13
# 	Total Evacuated = 87
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 103
# Total agent = 100
# 	Total Unevacuated = 13
# 	Total Evacuated = 87
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 104
# Total agent = 100
# 	Total Unevacuated = 13
# 	Total Evacuated = 87
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 105
# Total agent = 100
# 	Total Unevacuated = 13
# 	Total Evacuated = 87
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 106
# Total agent = 100
# 	Total Unevacuated = 13
# 	Total Evacuated = 87
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 107
# Total agent = 100
# 	Total Unevacuated = 13
# 	Total Evacuated = 87
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 108
# Total agent = 100
# 	Total Unevacuated = 13
# 	Total Evacuated = 87
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 109
# Total agent = 100
# 	Total Unevacuated = 13
# 	Total Evacuated = 87
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 110
# Total agent = 100
# 	Total Unevacuated = 13
# 	Total Evacuated = 87
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 111
# Total agent = 100
# 	Total Unevacuated = 13
# 	Total Evacuated = 87
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 112
# Total agent = 100
# 	Total Unevacuated = 13
# 	Total Evacuated = 87
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 113
# Total agent = 100
# 	Total Unevacuated = 13
# 	Total Evacuated = 87
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 114
# Total agent = 100
# 	Total Unevacuated = 13
# 	Total Evacuated = 87
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 115
# Total agent = 100
# 	Total Unevacuated = 13
# 	Total Evacuated = 87
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Evacpoint full, finding next evac point
# Step count = 116
# Total agent = 100
# 	Total Unevacuated = 13
# 	Total Evacuated = 87
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 117
# Total agent = 100
# 	Total Unevacuated = 13
# 	Total Evacuated = 87
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Step count = 118
# Total agent = 100
# 	Total Unevacuated = 13
# 	Total Evacuated = 87
# Total Evac Point = 10
# 	Total Filled Evac Point = 6
#
# Evac Success
# Step count =