# %% [markdown]
# # Load Library
# load global library

# %%
import sys
import os

# %% [markdown]
# load local library

# %%
sys.path.append(os.path.join(os.getcwd() , ".."))
import lib.Map.Map as map
import lib.Renderer.Renderer as renderer
import lib.Simulation.Simulation as simulation

# %%
print(map.Map.__doc__)
# Out:
#     [Class] Map
#     A class to represent the map
#
#     Properties:
#         - minlat : minimum latitude.
#         - minlon : minimum longitude.
#         - maxlat : maximum latitute.
#         - maxlon : maximum longitude.
#         - num_nodes : Number of Nodes.
#         - nodesDict : Dictionary of all nodes. The key used are the Open Street Map ID.
#         - nodes : List of all nodes.
#         - num_ways : Number of Ways.
#         - waysDict : Dictionary of all nodes. The key used are the Open Street Map ID.
#         - ways : List of all ways.
#         - roadsDict : List of all nodes that marked as road.
#         - roads : List of all roads.

# %%
print(map.readFile.__doc__)
# Out:
#     [Function] readFile
#     Function to generate map fom osm File
#
#     parameter:
#         - filepath : path to the OSM file

# %%
dataDirectory = os.path.join("..","osmdata")
filename = "TX-To-TU.osm"
filepath = os.path.join(dataDirectory,filename)

# %%
osmMap = map.readFile(filepath)

# %%
print(osmMap)
# Out:
# Namazu Map
#  number of nodes = 22469
#  number of ways = 3681
#  number of roads = 8134
#  number of roads node = 7270
#  number of building = 1768

# %%
sim = simulation.Simulation(osmMap)

# %%
sim.buildCells()

sim.initialize(agents= 200,agentsWithERI=100,evac= 15,capacity=50,numberOfThread= 4)
# Out:
# Starting Thread-1Starting Thread-2
# Thread-2->Processing = 1/50 agents
# Thread-2->Processing = 2/50 agents
# Thread-2->Processing = 3/50 agents
# Thread-2->Processing = 4/50 agents
#
# Thread-1->Processing = 1/50 agents
# Thread-1->Processing = 2/50 agents
# Thread-1->Processing = 3/50 agents
# Thread-1->Processing = 4/50 agents
# Thread-1->Processing = 5/50 agents
# Thread-1->Processing = 6/50 agents
# Thread-1->Processing = 7/50 agents
# Thread-1->Processing = 8/50 agents
# Thread-1->Processing = 9/50 agents
# Thread-1->Processing = 10/50 agents
# Thread-1->Processing = 11/50 agents
# Thread-1->Processing = 12/50 agents
# Thread-1->Processing = 13/50 agentsThread-2->Processing = 5/50 agents
# Thread-2->Processing = 6/50 agents
# Thread-2->Processing = 7/50 agents
# Thread-2->Processing = 8/50 agents
# Thread-2->Processing = 9/50 agents
# Thread-2->Processing = 10/50 agents
# Thread-2->Processing = 11/50 agents
# Thread-2->Processing = 12/50 agents
# Thread-1->Processing = 14/50 agents
# Thread-1->Processing = 15/50 agents
#
# Thread-2->Processing = 13/50 agents
# Thread-2->Processing = 14/50 agents
# Thread-2->Processing = 15/50 agents
# Starting Thread-3Thread-2->Processing = 16/50 agents
# Thread-2->Processing = 17/50 agents
# Thread-2->Processing = 18/50 agents
# Thread-2->Processing = 19/50 agents
# Thread-2->Processing = 20/50 agents
# Thread-2->Processing = 21/50 agents
# Thread-2->Processing = 22/50 agents
# Thread-2->Processing = 23/50 agents
# Thread-2->Processing = 24/50 agents
# Thread-2->Processing = 25/50 agents
# Thread-2->Processing = 26/50 agents
# Thread-2->Processing = 27/50 agents
# Thread-2->Processing = 28/50 agents
# Thread-2->Processing = 29/50 agents
# Thread-2->Processing = 30/50 agents
# Thread-2->Processing = 31/50 agents
# Thread-2->Processing = 32/50 agentsThread-1->Processing = 16/50 agents
# Thread-1->Processing = 17/50 agents
# Thread-1->Processing = 18/50 agents
# Thread-1->Processing = 19/50 agents
# Thread-1->Processing = 20/50 agents
# Thread-1->Processing = 21/50 agents
# Thread-1->Processing = 22/50 agents
#
# Thread-1->Processing = 23/50 agents
# Thread-3->Processing = 1/50 agents
# Thread-3->Processing = 2/50 agents
# Thread-3->Processing = 3/50 agentsThread-1->Processing = 24/50 agents
# Thread-1->Processing = 25/50 agents
# Thread-1->Processing = 26/50 agents
# Thread-1->Processing = 27/50 agents
# Thread-1->Processing = 28/50 agents
# Thread-1->Processing = 29/50 agents
# Thread-1->Processing = 30/50 agents
# Thread-1->Processing = 31/50 agents
# Thread-1->Processing = 32/50 agents
# Thread-1->Processing = 33/50 agents
# Thread-1->Processing = 34/50 agents
#
# Thread-3->Processing = 4/50 agents
#
# Thread-2->Processing = 33/50 agents
# Thread-2->Processing = 34/50 agents
# Thread-2->Processing = 35/50 agents
# Thread-2->Processing = 36/50 agents
# Thread-2->Processing = 37/50 agents
# Thread-2->Processing = 38/50 agents
# Thread-2->Processing = 39/50 agents
# Thread-2->Processing = 40/50 agentsThread-1->Processing = 35/50 agents
# Thread-1->Processing = 36/50 agents
# Thread-1->Processing = 37/50 agents
# Thread-1->Processing = 38/50 agents
# Thread-1->Processing = 39/50 agents
# Thread-1->Processing = 40/50 agents
# Thread-1->Processing = 41/50 agents
# Thread-1->Processing = 42/50 agents
# Thread-1->Processing = 43/50 agents
# Thread-1->Processing = 44/50 agents
# Thread-1->Processing = 45/50 agents
# Thread-1->Processing = 46/50 agents
# Thread-1->Processing = 47/50 agents
# Thread-1->Processing = 48/50 agents
# Thread-1->Processing = 49/50 agents
# Thread-1->Processing = 50/50 agents
# Thread-1->finished
# Exiting Thread-1
#
# Starting Thread-4Thread-3->Processing = 5/50 agentsThread-2->Processing = 41/50 agents
# Thread-3->Processing = 6/50 agents
# Thread-3->Processing = 7/50 agents
# Thread-3->Processing = 8/50 agents
# Thread-3->Processing = 9/50 agents
# Thread-3->Processing = 10/50 agents
# Thread-3->Processing = 11/50 agents
# Thread-3->Processing = 12/50 agents
# Thread-3->Processing = 13/50 agents
# Thread-3->Processing = 14/50 agents
# Thread-3->Processing = 15/50 agents
# Thread-3->Processing = 16/50 agents
# Thread-3->Processing = 17/50 agents
# Thread-3->Processing = 18/50 agents
# Thread-3->Processing = 19/50 agents
# Thread-3->Processing = 20/50 agents
# Thread-3->Processing = 21/50 agents
# Thread-3->Processing = 22/50 agents
# Thread-3->Processing = 23/50 agents
# Thread-3->Processing = 24/50 agents
# Thread-3->Processing = 25/50 agents
# Thread-3->Processing = 26/50 agents
# Thread-3->Processing = 27/50 agents
# 50
#
#
# Thread-3->Processing = 28/50 agentsThread-2->Processing = 42/50 agentsThread-4->Processing = 1/50 agents
# Thread-4->Processing = 2/50 agents
# Thread-4->Processing = 3/50 agents
# Thread-4->Processing = 4/50 agents
#
# Thread-3->Processing = 29/50 agentsThread-2->Processing = 43/50 agents
# Thread-4->Processing = 5/50 agents
# Thread-4->Processing = 6/50 agents
# Thread-4->Processing = 7/50 agents
# Thread-4->Processing = 8/50 agents
# Thread-4->Processing = 9/50 agents
# Thread-4->Processing = 10/50 agents
# Thread-4->Processing = 11/50 agents
# Thread-4->Processing = 12/50 agents
# Thread-4->Processing = 13/50 agents
# Thread-4->Processing = 14/50 agents
# Thread-4->Processing = 15/50 agents
#
# Thread-4->Processing = 16/50 agents
# Thread-3->Processing = 30/50 agents
# Thread-3->Processing = 31/50 agentsThread-2->Processing = 44/50 agents
# Thread-2->Processing = 45/50 agents
# Thread-2->Processing = 46/50 agents
# Thread-2->Processing = 47/50 agents
# Thread-2->Processing = 48/50 agents
# Thread-2->Processing = 49/50 agents
# Thread-2->Processing = 50/50 agents
# Thread-2->finished
# Exiting Thread-2
#
#
# 50Thread-4->Processing = 17/50 agents
# Thread-4->Processing = 18/50 agents
# Thread-4->Processing = 19/50 agentsThread-3->Processing = 32/50 agents
# Thread-3->Processing = 33/50 agents
# Thread-4->Processing = 20/50 agents
# Thread-4->Processing = 21/50 agents
# Thread-4->Processing = 22/50 agents
# Thread-4->Processing = 23/50 agents
#
# Thread-3->Processing = 34/50 agents
# Thread-3->Processing = 35/50 agents
#
# Thread-3->Processing = 36/50 agents
# Thread-4->Processing = 24/50 agents
# Thread-4->Processing = 25/50 agentsThread-3->Processing = 37/50 agents
# Thread-3->Processing = 38/50 agents
# Thread-3->Processing = 39/50 agents
# Thread-3->Processing = 40/50 agents
# Thread-3->Processing = 41/50 agents
# Thread-3->Processing = 42/50 agents
# Thread-3->Processing = 43/50 agents
# Thread-3->Processing = 44/50 agents
# Thread-3->Processing = 45/50 agents
# Thread-3->Processing = 46/50 agents
# Thread-3->Processing = 47/50 agents
# Thread-3->Processing = 48/50 agents
# Thread-3->Processing = 49/50 agents
# Thread-3->Processing = 50/50 agents
# Thread-3->finished
# Exiting Thread-3
#
# Thread-4->Processing = 26/50 agents
# Thread-4->Processing = 27/50 agents
# Thread-4->Processing = 28/50 agents
# Thread-4->Processing = 29/50 agents
# Thread-4->Processing = 30/50 agents
# Thread-4->Processing = 31/50 agents
# Thread-4->Processing = 32/50 agents
# Thread-4->Processing = 33/50 agents
# 50Thread-4->Processing = 34/50 agents
#
# Thread-4->Processing = 35/50 agents
# Thread-4->Processing = 36/50 agents
# Thread-4->Processing = 37/50 agents
# Thread-4->Processing = 38/50 agents
# Thread-4->Processing = 39/50 agents
# Thread-4->Processing = 40/50 agents
# Thread-4->Processing = 41/50 agents
# Thread-4->Processing = 42/50 agents
# Thread-4->Processing = 43/50 agents
# Thread-4->Processing = 44/50 agents
# Thread-4->Processing = 45/50 agents
# Thread-4->Processing = 46/50 agents
# Thread-4->Processing = 47/50 agents
# Thread-4->Processing = 48/50 agents
# Thread-4->Processing = 49/50 agents
# Thread-4->Processing = 50/50 agents
# Thread-4->finished
# Exiting Thread-4
# 50
# Finished generating agents Without ERI
# Starting Thread-1Starting Thread-2
#
# Starting Thread-3
# Starting Thread-4
# Thread-3->Processing = 1/25 agents
# Thread-3->Processing = 2/25 agents
# Thread-3->Processing = 3/25 agents
# Thread-3->Processing = 4/25 agents
# Thread-2->Processing = 1/25 agents
# Thread-3->Processing = 5/25 agents
# Thread-3->Processing = 6/25 agents
# Thread-1->Processing = 1/25 agents
# Thread-1->Processing = 2/25 agents
# Thread-2->Processing = 2/25 agents
# Thread-1->Processing = 3/25 agents
# Thread-1->Processing = 4/25 agents
# Thread-2->Processing = 3/25 agents
# Thread-2->Processing = 4/25 agents
# Thread-1->Processing = 5/25 agents
# Thread-1->Processing = 6/25 agents
# Thread-2->Processing = 5/25 agents
# Thread-4->Processing = 1/25 agents
# Thread-2->Processing = 6/25 agents
# Thread-4->Processing = 2/25 agents
# Thread-4->Processing = 3/25 agents
# Thread-3->Processing = 7/25 agents
# Thread-4->Processing = 4/25 agents
# Thread-2->Processing = 7/25 agents
# Thread-1->Processing = 7/25 agents
# Thread-1->Processing = 8/25 agents
# Thread-2->Processing = 8/25 agents
# Thread-3->Processing = 8/25 agents
# Thread-4->Processing = 5/25 agents
# Thread-4->Processing = 6/25 agents
# Thread-1->Processing = 9/25 agents
# Thread-2->Processing = 9/25 agents
# Thread-4->Processing = 7/25 agents
# Thread-3->Processing = 9/25 agents
# Thread-1->Processing = 10/25 agents
# Thread-1->Processing = 11/25 agents
# Thread-3->Processing = 10/25 agents
# Thread-4->Processing = 8/25 agents
# Thread-1->Processing = 12/25 agents
# Thread-1->Processing = 13/25 agents
# Thread-3->Processing = 11/25 agents
# Thread-2->Processing = 10/25 agents
# Thread-1->Processing = 14/25 agents
# Thread-3->Processing = 12/25 agents
# Thread-3->Processing = 13/25 agents
# Thread-1->Processing = 15/25 agents
# Thread-3->Processing = 14/25 agents
# Thread-2->Processing = 11/25 agents
# Thread-3->Processing = 15/25 agents
# Thread-3->Processing = 16/25 agents
# Thread-2->Processing = 12/25 agents
# Thread-3->Processing = 17/25 agents
# Thread-3->Processing = 18/25 agents
# Thread-1->Processing = 16/25 agentsThread-2->Processing = 13/25 agents
#
# Thread-1->Processing = 17/25 agents
# Thread-1->Processing = 18/25 agents
# Thread-2->Processing = 14/25 agents
# Thread-1->Processing = 19/25 agents
# Thread-2->Processing = 15/25 agents
# Thread-3->Processing = 19/25 agents
# Thread-3->Processing = 20/25 agents
# Thread-3->Processing = 21/25 agents
# Thread-2->Processing = 16/25 agents
# Thread-4->Processing = 9/25 agents
# Thread-3->Processing = 22/25 agents
# Thread-4->Processing = 10/25 agents
# Thread-3->Processing = 23/25 agents
# Thread-3->Processing = 24/25 agents
# Thread-2->Processing = 17/25 agents
# Thread-2->Processing = 18/25 agents
# Thread-2->Processing = 19/25 agents
# Thread-2->Processing = 20/25 agents
# Thread-2->Processing = 21/25 agentsThread-4->Processing = 11/25 agents
# Thread-3->Processing = 25/25 agents
# Thread-3->finished
# Exiting Thread-3
#
# Thread-4->Processing = 12/25 agents
# Thread-4->Processing = 13/25 agents
# Thread-1->Processing = 20/25 agents
# Thread-2->Processing = 22/25 agents
# Thread-2->Processing = 23/25 agents
# Thread-4->Processing = 14/25 agents
# Thread-1->Processing = 21/25 agents
# Thread-2->Processing = 24/25 agents
# Thread-4->Processing = 15/25 agents
# Thread-2->Processing = 25/25 agents
# Thread-2->finished
# Exiting Thread-2
# Thread-4->Processing = 16/25 agents
# Thread-1->Processing = 22/25 agents
# Thread-1->Processing = 23/25 agents
# Thread-4->Processing = 17/25 agents
# Thread-4->Processing = 18/25 agents
# Thread-4->Processing = 19/25 agents
# Thread-1->Processing = 24/25 agents
# Thread-4->Processing = 20/25 agents
# Thread-4->Processing = 21/25 agents
# Thread-1->Processing = 25/25 agents
# Thread-1->finished
# Exiting Thread-1
# 25
# 25
# 25
# Thread-4->Processing = 22/25 agents
# Thread-4->Processing = 23/25 agents
# Thread-4->Processing = 24/25 agents
# Thread-4->Processing = 25/25 agents
# Thread-4->finished
# Exiting Thread-4
# 25
# Finished generating agents With ERI

# %%
renderer.render(osmMap,sim)
# Out:
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Evac Success
# Evac Success
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Evac Success
# Evac Success
# Sharing knowledge
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Evac Success
# Evac Success
# Sharing knowledge
# Sharing knowledge
# Evac Success
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Evac Success
# Sharing knowledge
# Sharing knowledge
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Evac Success
# Evac Success
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Sharing knowledge
# Sharing knowledge
# Evac Success
# Evac Success
# Evac Success
# Sharing knowledge
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Sharing knowledge
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Sharing knowledge
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Sharing knowledge
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Sharing knowledge
# Evac Success
# Sharing knowledge
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Sharing knowledge
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Sharing knowledge
# Evac Success
# Evac Success
# Evac Success
# Sharing knowledge
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Sharing knowledge
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Sharing knowledge
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Sharing knowledge
# Evac Success
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Sharing knowledge
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Sharing knowledge
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Sharing knowledge
# Evac Success
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Sharing knowledge
# Evac Success
# Evac Success
# Sharing knowledge
# Evac Success
# Evac Success
# Sharing knowledge
# Evac Success
# Evac Success
# Evac Success
# Sharing knowledge
# Evac Success
# Evac Success
# Evac Success
# Sharing knowledge
# Sharing knowledge
# Evac Success
# Evac Success
# Sharing knowledge
# Evac Success
# Evac Success
# Evac Success
# Evac Success
# Sharing knowledge
# Sharing knowledge
# Evac Success
# Sharing knowledge
# Evac Success
# Sharing knowledge
# Evac Success
# Sharing knowledge
# Evac Success
# Sharing knowledge
# Evac Success
# Sharing knowledge
# Evac Success
# Evac Success
# Evac Success
# Sharing knowledge
# Sharing knowledge
# Sharing knowledge
# Evac Success
# Evac Success
# Evac Success
# Sharing knowledge
# Evac Success
# Sharing knowledge
# Evac Success
# Sharing knowledge
# Evac Success
# Sharing knowledge
# Evac Success
# Sharing knowledge
# Evac Success
# Sharing knowledge
# Evac Success
# Sharing knowledge
# Evac Success
# Sharing knowledge
# Evac Success
# Sharing knowledge
# Evac Success
# Sharing knowledge
# Evac Success
# Sharing knowledge
# Sharing knowledge
# Evac Success
# Evac Success
# Sharing knowledge
# Evac Success
# Sharing knowledge
# Evac Success
# Sharing knowledge
# Evac Success
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-e52f32bbc69a> in <module>
# ----> 1 renderer.render(osmMap,sim)
#
# ~/Desktop/Study/Namazu/demo/../lib/Renderer/Renderer.py in render(map, simulation, path)
#     321     if (sim is not None):
#     322         drawAgent()
# --> 323     root.mainloop()
#
# /usr/lib/python3.6/tkinter/__init__.py in mainloop(self, n)
#    1281     def mainloop(self, n=0):
#    1282         """Call the mainloop of Tk."""
# -> 1283         self.tk.mainloop(n)
#    1284     def quit(self):
#    1285         """Quit the Tcl interpreter. All widgets will be destroyed."""
#
# KeyboardInterrupt:
